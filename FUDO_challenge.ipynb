# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# # Recorridos

# %%
# importo los modulos requeridos
import zipfile
import pandas as pd

# Leo el dataset desde un zip
df_tours_tomados = pd.read_csv('/content/gdrive/MyDrive/Fudo Ejercicio/recorridos-realizados-2023.zip', compression='zip')

df_tours_tomados.head(10)
# Out:
#    Unnamed: 0       Id_recorrido duracion_recorrido fecha_origen_recorrido  \
# 0           1  17910696BAEcobici              1,848    2023-04-24 10:30:10
# 1           2  17600256BAEcobici                288    2023-03-22 17:40:55
# 2           3  17255670BAEcobici              1,103    2023-02-15 23:12:22
# 3           4  17996972BAEcobici              1,165    2023-05-03 11:00:20
# 4           5  17148836BAEcobici                378    2023-02-06 06:50:58
# 5           6  16817654BAEcobici                747    2023-01-03 16:40:06
# 6           7  17248854BAEcobici                634    2023-02-15 14:42:52
# 7           8  18036735BAEcobici                944    2023-05-08 09:55:46
# 8           9  17993884BAEcobici              1,353    2023-05-03 01:47:34
# 9          10  16944859BAEcobici              1,565    2023-01-16 19:31:36
#
#   id_estacion_origen                     nombre_estacion_origen  \
# 0       358BAEcobici                               249 - Balbín
# 1       444BAEcobici               061 - Ministerio de Economia
# 2       280BAEcobici                        222 - SIMON BOLIVAR
# 3       273BAEcobici                               223 - GAINZA
# 4        65BAEcobici                       065 - Julián Álvarez
# 5       477BAEcobici  311 - SEC. DE INNOVACION Y TRANSFORMACIÓN
# 6       182BAEcobici                182 - RAVIGNANI Y GUATEMALA
# 7        66BAEcobici                         066 - Billinghurst
# 8       132BAEcobici                           132 - CORRIENTES
# 9        91BAEcobici                                091 - Pasco
#
#                  direccion_estacion_origen  long_estacion_origen  \
# 0                              2519 Conesa            -58.465586
# 1        Balcarce e Yrigoyen, Hipolito Av.            -58.370716
# 2         1701 Fernandez Moreno, Baldomero            -58.449379
# 3             494 Gainza, Martin De, Gral.            -58.446751
# 4                              3822 Guemes            -58.415787
# 5                         Av. Caseros 2309            -58.395054
# 6  2185 Ravignani, Emilio, Dr. & Guatemala            -58.435247
# 7                             3508 Carcova            -58.413871
# 8             Reconquista & Corrientes Av.            -58.372763
# 9                        708 Pasco & Chile            -58.397602
#
#    lat_estacion_origen fecha_destino_recorrido id_estacion_destino  \
# 0           -34.561486     2023-04-24 11:00:58        278BAEcobici
# 1           -34.608936     2023-03-22 17:45:43          3BAEcobici
# 2           -34.633528     2023-02-15 23:30:45        280BAEcobici
# 3           -34.616758     2023-05-03 11:19:45        367BAEcobici
# 4           -34.587312     2023-02-06 06:57:16         14BAEcobici
# 5           -34.635005     2023-01-03 16:52:33        477BAEcobici
# 6           -34.578048     2023-02-15 14:53:26        229BAEcobici
# 7           -34.594547     2023-05-08 10:11:30        242BAEcobici
# 8           -34.603369     2023-05-03 02:10:07         75BAEcobici
# 9           -34.617448     2023-01-16 19:57:41        254BAEcobici
#
#                      nombre_estacion_destino  \
# 0                               233 - MONROE
# 1                               003 - ADUANA
# 2                        222 - SIMON BOLIVAR
# 3                          287 - Belaustegui
# 4                             014 - Pacifico
# 5  311 - SEC. DE INNOVACION Y TRANSFORMACIÓN
# 6           243 - PLAZOLETA CELEDONIO FLORES
# 7                                103 - MALBA
# 8                075 - Plaza Primero de Mayo
# 9                        276 - PRIMERA JUNTA
#
#           direccion_estacion_destino  long_estacion_destino  \
# 0                        2519 Superi             -58.469813
# 1                  Moreno & Azopardo             -58.368174
# 2   1701 Fernandez Moreno, Baldomero             -58.449379
# 3        Belaustegui, Luis, Dr. 2890             -58.477209
# 4  Santa Fe Av. & Bullrich, Int. Av.             -58.426387
# 5                   Av. Caseros 2309             -58.395054
# 6                       Cordoba 6599             -58.451530
# 7    Av. Pres. Figueroa Alcorta 3451             -58.403984
# 8                      238 Pichincha             -58.398987
# 9                           Rojas 60             -58.441868
#
#    lat_estacion_destino       id_usuario modelo_bicicleta  género
# 0            -34.564122  861866BAEcobici           ICONIC    MALE
# 1            -34.611102  217525BAEcobici           ICONIC  FEMALE
# 2            -34.633528  954201BAEcobici           ICONIC    MALE
# 3            -34.616212  179414BAEcobici           ICONIC    MALE
# 4            -34.577424    8098BAEcobici           ICONIC    MALE
# 5            -34.635005  940830BAEcobici           ICONIC    MALE
# 6            -34.581576  727902BAEcobici           ICONIC    MALE
# 7            -34.576949  961810BAEcobici           ICONIC    MALE
# 8            -34.612298  979125BAEcobici           ICONIC    MALE
# 9            -34.619657   93862BAEcobici           ICONIC    MALE

# %%
len(df_tours_tomados.index)
# Out:
# 2622331

# %%
df_tours_tomados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2622331 entries, 0 to 2622330
# Data columns (total 18 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   Unnamed: 0                  int64
#  1   Id_recorrido                object
#  2   duracion_recorrido          object
#  3   fecha_origen_recorrido      object
#  4   id_estacion_origen          object
#  5   nombre_estacion_origen      object
#  6   direccion_estacion_origen   object
#  7   long_estacion_origen        float64
#  8   lat_estacion_origen         float64
#  9   fecha_destino_recorrido     object
#  10  id_estacion_destino         object
#  11  nombre_estacion_destino     object
#  12  direccion_estacion_destino  object
#  13  long_estacion_destino       float64
#  14  lat_estacion_destino        float64
#  15  id_usuario                  object
#  16  modelo_bicicleta            object
#  17  género                      object
# dtypes: float64(4), int64(1), object(13)
# memory usage: 360.1+ MB

# %% [markdown]
# Como podemos ver, el set de datos, tiene valores nulos. Y corresponden a los datos de la estacion de destino.

# %%
# Busco por valores nulos en el dataframe de estaciones
df_tours_tomados.isnull().values.any()
# Out:
# True

# %%
# Me fijo que columnas tienen missing values y cuantos
df_tours_tomados.isnull().sum()
# Out:
# Unnamed: 0                        0
# Id_recorrido                      0
# duracion_recorrido                0
# fecha_origen_recorrido            0
# id_estacion_origen                0
# nombre_estacion_origen            0
# direccion_estacion_origen         0
# long_estacion_origen              0
# lat_estacion_origen               0
# fecha_destino_recorrido           0
# id_estacion_destino               2
# nombre_estacion_destino           2
# direccion_estacion_destino        2
# long_estacion_destino             2
# lat_estacion_destino              2
# id_usuario                        0
# modelo_bicicleta                  0
# género                        11966
# dtype: int64

# %% [markdown]
# ## Preprocesamiento Recorridos

# %% [markdown]
# Eliminamos las columnas innecesarias, ya que se pueden inferir de las otras tablas

# %%
columnas_a_retirar = [
  'género',
  'lat_estacion_destino',
  'long_estacion_destino',
  'direccion_estacion_destino',
  'nombre_estacion_destino',
  'lat_estacion_origen',
  'long_estacion_origen',
  'direccion_estacion_origen',
  'nombre_estacion_origen',
  'Unnamed: 0',
]

df_tours_tomados.drop(columnas_a_retirar, axis=1, inplace=True)
df_tours_tomados.head(5)
# Out:
#         Id_recorrido duracion_recorrido fecha_origen_recorrido  \
# 0  17910696BAEcobici              1,848    2023-04-24 10:30:10
# 1  17600256BAEcobici                288    2023-03-22 17:40:55
# 2  17255670BAEcobici              1,103    2023-02-15 23:12:22
# 3  17996972BAEcobici              1,165    2023-05-03 11:00:20
# 4  17148836BAEcobici                378    2023-02-06 06:50:58
#
#   id_estacion_origen fecha_destino_recorrido id_estacion_destino  \
# 0       358BAEcobici     2023-04-24 11:00:58        278BAEcobici
# 1       444BAEcobici     2023-03-22 17:45:43          3BAEcobici
# 2       280BAEcobici     2023-02-15 23:30:45        280BAEcobici
# 3       273BAEcobici     2023-05-03 11:19:45        367BAEcobici
# 4        65BAEcobici     2023-02-06 06:57:16         14BAEcobici
#
#         id_usuario modelo_bicicleta
# 0  861866BAEcobici           ICONIC
# 1  217525BAEcobici           ICONIC
# 2  954201BAEcobici           ICONIC
# 3  179414BAEcobici           ICONIC
# 4    8098BAEcobici           ICONIC

# %% [markdown]
# Limpiamos los ID, ya que estan ensuciados con el texto "BAEcobici"

# %%
df_tours_tomados = df_tours_tomados.rename(columns={'Id_recorrido': 'id_recorrido'})

df_tours_tomados.replace({'BAEcobici': ''}, inplace=True, regex=True)
df_tours_tomados.head(5)

# %% [markdown]
# Casteamos los valores a sus correspondientes tipos, preservando los regsitros con valores nulos

# %%
df_tours_tomados["duracion_recorrido"].replace({',': ''}, inplace=True, regex=True)

df_tours_tomados['fecha_destino_recorrido'] = df_tours_tomados['fecha_destino_recorrido'].astype(str)
df_tours_tomados['fecha_origen_recorrido'] = df_tours_tomados['fecha_origen_recorrido'].astype(str)

print(df_tours_tomados.dtypes)
# Out:
# id_recorrido               object
# duracion_recorrido         object
# fecha_origen_recorrido     object
# id_estacion_origen         object
# fecha_destino_recorrido    object
# id_estacion_destino        object
# id_usuario                 object
# modelo_bicicleta           object
# dtype: object

# %% [markdown]
# Como se puede apreciar, se preservo ambos registros con el id de estacion destino nulo

# %%
df_tours_tomados.isnull().sum()
# Out:
# id_recorrido               0
# duracion_recorrido         0
# fecha_origen_recorrido     0
# id_estacion_origen         0
# fecha_destino_recorrido    0
# id_estacion_destino        2
# id_usuario                 0
# modelo_bicicleta           0
# dtype: int64

# %% [markdown]
# Tambien podemos observar que si bien no se sabe cual fue la estacion destino, si hay informacion de la fecha de destino, cuanto duro el recorrido y que usuario fue. Por lo que es posible asumir que las bicis fueron devueltas y simplemente hubo una falla al registrar la devolucion de las bicis. Esto hay que tenerlo en cuenta a la hora de hacer consultas sobre los datos.

# %%
df_tours_tomados_sin_destino = df_tours_tomados.loc[df_tours_tomados['id_estacion_destino'].isnull()]
df_tours_tomados_sin_destino
# Out:
#         id_recorrido duracion_recorrido fecha_origen_recorrido  \
# 2111365     19632972               1372    2023-11-08 09:37:57
# 2177905     19632583                466    2023-11-08 09:08:31
#
#         id_estacion_origen fecha_destino_recorrido id_estacion_destino  \
# 2111365                 26     2023-11-08 10:00:49                 NaN
# 2177905                 38     2023-11-08 09:16:17                 NaN
#
#         id_usuario modelo_bicicleta
# 2111365    1020610              FIT
# 2177905     774845              FIT

# %%
df_tours_tomados.head(5)
# Out:
#   id_recorrido duracion_recorrido fecha_origen_recorrido id_estacion_origen  \
# 0     17910696               1848    2023-04-24 10:30:10                358
# 1     17600256                288    2023-03-22 17:40:55                444
# 2     17255670               1103    2023-02-15 23:12:22                280
# 3     17996972               1165    2023-05-03 11:00:20                273
# 4     17148836                378    2023-02-06 06:50:58                 65
#
#   fecha_destino_recorrido id_estacion_destino id_usuario modelo_bicicleta
# 0     2023-04-24 11:00:58                 278     861866           ICONIC
# 1     2023-03-22 17:45:43                   3     217525           ICONIC
# 2     2023-02-15 23:30:45                 280     954201           ICONIC
# 3     2023-05-03 11:19:45                 367     179414           ICONIC
# 4     2023-02-06 06:57:16                  14       8098           ICONIC

# %%
df_tours_tomados["duracion_recorrido"] = df_tours_tomados["duracion_recorrido"].astype(int)

# %%
df_tours_tomados["duracion_recorrido"].min()
# Out:
# 61

# %%
df_tours_tomados["duracion_recorrido"].max()
# Out:
# 6208259

# %%
df_tours_tomados.dtypes
# Out:
# id_recorrido               object
# duracion_recorrido          int64
# fecha_origen_recorrido     object
# id_estacion_origen         object
# fecha_destino_recorrido    object
# id_estacion_destino        object
# id_usuario                 object
# modelo_bicicleta           object
# dtype: object

# %% [markdown]
# # Estaciones de bici

# %%
df_estaciones = pd.read_csv('/content/gdrive/MyDrive/Fudo Ejercicio/nuevas-estaciones-bicicletas-publicas.csv', sep=';', encoding='latin-1')
df_estaciones.head(5)
# Out:
#    ID Comet  NÚMERO de Estación          NOMBRE  \
# 0         2                    2       RETIRO I
# 1         3                    3         ADUANA
# 2         4                    4     PLAZA ROMA
# 3         5                    5   PLAZA ITALIA
# 4         6                    6  PARQUE LEZAMA
#
#                              DIRECCIÓN       BARRIO     COMUNA EMPLAZAMIENTO  \
# 0  Av. Dr. José María Ramos Mejía 1300       RETIRO   COMUNA 1         PLAZA
# 1                             Moreno 4    MONSERRAT   COMUNA 1        VEREDA
# 2                   Av. Corrientes 100  SAN NICOLAS   COMUNA 1        VEREDA
# 3                  Av. Sarmiento 2601       PALERMO  COMUNA 14        VEREDA
# 4               Av. Martín Garcia 295     SAN TELMO   COMUNA 1         PLAZA
#
#      LATITUD   LONGITUD
# 0 -34.592424 -58.374710
# 1 -34.611100 -58.368200
# 2 -34.602995  58.368832
# 3 -34.580700 -58.420400
# 4 -34.628300 -58.369400

# %%
df_estaciones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID Comet             360 non-null    int64
#  1   NÚMERO de Estación   360 non-null    int64
#  2   NOMBRE               360 non-null    object
#  3   DIRECCIÓN            360 non-null    object
#  4   BARRIO               360 non-null    object
#  5   COMUNA               360 non-null    object
#  6   EMPLAZAMIENTO        360 non-null    object
#  7   LATITUD              360 non-null    float64
#  8   LONGITUD             360 non-null    float64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 25.4+ KB

# %%
df_estaciones.isnull().values.any()
# Out:
# False

# %%
len(df_estaciones.index)
# Out:
# 360

# %% [markdown]
# ## Prepocesamiento estaciones de bici

# %% [markdown]
# Renombramos las columnas para unificar y simplificar el llamado de las mismas

# %%
df_estaciones = df_estaciones.rename(columns={
    'ID Comet': 'id_comet',
    'NÚMERO de Estación ': 'nro_de_estacion',
    'NOMBRE': 'nombre',
    'DIRECCIÓN': 'direccion',
    'BARRIO': 'barrio',
    'COMUNA': 'comuna',
    'EMPLAZAMIENTO': 'emplazamiento',
    'LATITUD': 'latitud',
    'LONGITUD': 'longitud',
    })

df_estaciones.head(5)
# Out:
#    id_comet  nro_de_estacion         nombre  \
# 0         2                2       RETIRO I
# 1         3                3         ADUANA
# 2         4                4     PLAZA ROMA
# 3         5                5   PLAZA ITALIA
# 4         6                6  PARQUE LEZAMA
#
#                              direccion       barrio     comuna emplazamiento  \
# 0  Av. Dr. José María Ramos Mejía 1300       RETIRO   COMUNA 1         PLAZA
# 1                             Moreno 4    MONSERRAT   COMUNA 1        VEREDA
# 2                   Av. Corrientes 100  SAN NICOLAS   COMUNA 1        VEREDA
# 3                  Av. Sarmiento 2601       PALERMO  COMUNA 14        VEREDA
# 4               Av. Martín Garcia 295     SAN TELMO   COMUNA 1         PLAZA
#
#      latitud   longitud
# 0 -34.592424 -58.374710
# 1 -34.611100 -58.368200
# 2 -34.602995  58.368832
# 3 -34.580700 -58.420400
# 4 -34.628300 -58.369400

# %%
len(df_estaciones.nro_de_estacion.unique())
# Out:
# 360

# %% [markdown]
# Es redundante que cada registro guarde el texto "comuna" cuando ya se sabe que esa columna representa que numero de comuna es. Por lo que se se simplifica a guardar el numero en si.

# %%
df_estaciones['comuna'].replace({'COMUNA ': ''}, inplace=True, regex=True)
df_estaciones.head(5)
# Out:
#    id_comet  nro_de_estacion         nombre  \
# 0         2                2       RETIRO I
# 1         3                3         ADUANA
# 2         4                4     PLAZA ROMA
# 3         5                5   PLAZA ITALIA
# 4         6                6  PARQUE LEZAMA
#
#                              direccion       barrio comuna emplazamiento  \
# 0  Av. Dr. José María Ramos Mejía 1300       RETIRO      1         PLAZA
# 1                             Moreno 4    MONSERRAT      1        VEREDA
# 2                   Av. Corrientes 100  SAN NICOLAS      1        VEREDA
# 3                  Av. Sarmiento 2601       PALERMO     14        VEREDA
# 4               Av. Martín Garcia 295     SAN TELMO      1         PLAZA
#
#      latitud   longitud
# 0 -34.592424 -58.374710
# 1 -34.611100 -58.368200
# 2 -34.602995  58.368832
# 3 -34.580700 -58.420400
# 4 -34.628300 -58.369400

# %% [markdown]
# # Usuarios

# %%
df_usuarios = pd.read_csv('/content/gdrive/MyDrive/Fudo Ejercicio/usuarios_ecobici_2023.csv')
df_usuarios.head(5)
# Out:
# <ipython-input-26-d43d43912883>:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_usuarios = pd.read_csv('/content/gdrive/MyDrive/Fudo Ejercicio/usuarios_ecobici_2023.csv')
#    ID_usuario genero_usuario edad_usuario  fecha_alta hora_alta  \
# 0     1083476           MALE           20  2023-12-31  19:24:57
# 1     1083080         FEMALE           18  2023-12-31  00:05:03
# 2     1083163          OTHER           27  2023-12-31  10:16:12
# 3     1083435           MALE           24  2023-12-31  17:42:11
# 4     1083376          OTHER           32  2023-12-31  16:16:15
#
#   Customer.Has.Dni..Yes...No.
# 0                         Yes
# 1                         Yes
# 2                          No
# 3                         Yes
# 4                          No

# %%
df_usuarios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136066 entries, 0 to 136065
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   ID_usuario                   136066 non-null  int64
#  1   genero_usuario               136066 non-null  object
#  2   edad_usuario                 136066 non-null  object
#  3   fecha_alta                   136066 non-null  object
#  4   hora_alta                    136066 non-null  object
#  5   Customer.Has.Dni..Yes...No.  136066 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 6.2+ MB

# %%
len(df_usuarios.index)
# Out:
# 136066

# %% [markdown]
# ## Usuarios preprocesamiento

# %% [markdown]
# - Estandarizamos los nombres de las columnas y los hacemos mas claros
# - Unificamos los valores de genero y DNI al espaniol
# - Se unifica la fecha y hora en un solo campo, tal cual esta en el dataset de recorridos

# %%
df_usuarios = df_usuarios.rename(columns={
    'ID_usuario': 'id_usuario',
    'genero_usuario': 'genero',
    'edad_usuario': 'edad',
    'Customer.Has.Dni..Yes...No.': 'posee_dni'
    })

df_usuarios['posee_dni'].replace({'Yes': 'Si'}, inplace=True, regex=True)
df_usuarios['genero'].replace({'MALE': 'HOMBRE', 'FEMALE': 'MUJER', 'OTHER': 'OTRO'}, inplace=True)

df_usuarios['fecha_alta'] = df_usuarios['fecha_alta'] + ' ' + df_usuarios['hora_alta']
df_usuarios.drop(['hora_alta'], axis=1, inplace=True)

df_usuarios.head(5)
# Out:
#    id_usuario  genero edad           fecha_alta posee_dni
# 0     1083476  HOMBRE   20  2023-12-31 19:24:57        Si
# 1     1083080   MUJER   18  2023-12-31 00:05:03        Si
# 2     1083163    OTRO   27  2023-12-31 10:16:12        No
# 3     1083435  HOMBRE   24  2023-12-31 17:42:11        Si
# 4     1083376    OTRO   32  2023-12-31 16:16:15        No

# %%
df_usuarios.posee_dni.unique()
# Out:
# array(['Si', 'No'], dtype=object)

# %%
df_usuarios.genero.unique()
# Out:
# array(['HOMBRE', 'MUJER', 'OTRO'], dtype=object)

# %%
df_usuarios.loc[df_usuarios['edad'] == '955']
# Out:
#         id_usuario genero edad           fecha_alta posee_dni
# 101506      979498   OTRO  955  2023-04-22 11:05:10        No

# %%
df_usuarios.loc[df_usuarios['edad'] == '-45']
# Out:
#        id_usuario genero edad           fecha_alta posee_dni
# 72750     1011253   OTRO  -45  2023-07-30 19:08:10        No

# %%
df_usuarios.loc[df_usuarios['id_usuario'] == 1063435]
# Out:
#        id_usuario genero   edad           fecha_alta posee_dni
# 20019     1063435   OTRO  1,015  2023-11-21 16:32:10        No

# %% [markdown]
# Algo que podemos notar es que hay usuarios con edades no enteras, edades muy chicas o muy grandes y edades negativas. La decision que tome es:
# - A las edades negativas, muy chicas o muy grandes. Eliminarlas del dataset. No tiene sentido una persona de 955 anios y tampoco tiene sentido que use una bici un bebe de 1 anio. Por lo que estos datos no son fiables al momento de consultar la edad del usuario
# - Si la edad de la persona tiene sentido pero es no entera, se redondea y se toma la edad de todas formas. Ej: una persona de 35.5 anios, tiene 35 anios, es un usuarios valido.
# - Tome un rango valido de edades de 10 anios a 80. Es debatible el rango pero considero que hay un limite de edad que un adulto mayor puede o deberia usar una bicicleta. Lo mismo para los menores.

# %%
df_usuarios['edad'].replace({',\d*': '', ' ': ''}, inplace=True,  regex=True)

# %%
df_usuarios["edad"] = df_usuarios["edad"].astype(int)

# %%
df_usuarios = df_usuarios[df_usuarios.edad >= 10]
df_usuarios = df_usuarios[df_usuarios.edad <= 80]

# %%
edad_max = df_usuarios['edad'].max()
edad_min = df_usuarios['edad'].min()
print(f"edad minima: {edad_min} \nedad maxima: {edad_max}")
# Out:
# edad minima: 14
# edad maxima: 80

# %%
df_usuarios.isnull().sum()
# Out:
# id_usuario    0
# genero        0
# edad          0
# fecha_alta    0
# posee_dni     0
# dtype: int64

# %%
df_usuarios.head(5)
# Out:
#    id_usuario  genero  edad           fecha_alta posee_dni
# 0     1083476  HOMBRE    20  2023-12-31 19:24:57        Si
# 1     1083080   MUJER    18  2023-12-31 00:05:03        Si
# 2     1083163    OTRO    27  2023-12-31 10:16:12        No
# 3     1083435  HOMBRE    24  2023-12-31 17:42:11        Si
# 4     1083376    OTRO    32  2023-12-31 16:16:15        No

# %% [markdown]
# ## Creacion de DBs SQL

# %%
import sys

print("Python version")

# Use the sys.version attribute to get the Python version and print it
print(sys.version)
# Print information about the Python version
print("Version info.")
# Use the sys.version_info attribute to get detailed version information and print it
print(sys.version_info)
# Out:
# Python version
# 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# Version info.
# sys.version_info(major=3, minor=10, micro=12, releaselevel='final', serial=0)

# %%
import sqlite3

conn = sqlite3.connect(database='ciclistas.db')

# %%
cursor = conn.cursor()

# %% [markdown]
# ### Tabla usuarios

# %%
create_usuarios_sql = "CREATE TABLE IF NOT EXISTS usuarios ( \
  id_usuario INTEGER PRIMARY KEY, \
  genero TEXT, \
  edad INTEGER NOT NULL, \
  fecha_alta TIMESTAMP, \
  posee_dni TEXT \
)"


cursor.execute(create_usuarios_sql)

# %%
cursor.executemany("INSERT INTO usuarios VALUES(?, ?, ?, ?, ?)", df_usuarios.values)
conn.commit()

# %% [markdown]
# ### Tabla estaciones

# %%
create_estaciones_sql = "CREATE TABLE IF NOT EXISTS estaciones ( \
  id_estacion INTEGER PRIMARY KEY, \
  nro_de_estacion INTEGER NOT NULL, \
  nombre TEXT, \
  direccion TEXT, \
  barrio TEXT, \
  comuna INTEGER, \
  emplazamiento TEXT, \
  latitud REAL, \
  longitud REAL \
);"

# Creo un indice secundario por comuna
#indice_id_comuna_sql = "CREATE INDEX idx_comuna ON estaciones (comuna);"


cursor = conn.cursor()
cursor.execute(create_estaciones_sql)
#cursor.execute(indice_id_comuna_sql)

# %%
cursor.executemany("INSERT INTO estaciones VALUES(?, ?, ?, ?, ?, ?, ?, ?, ?)", df_estaciones.values)
conn.commit()

# %% [markdown]
# ### Tabla recorridos

# %%
create_recorridos_sql = "CREATE TABLE IF NOT EXISTS recorridos ( \
  id_recorrido INTEGER PRIMARY KEY, \
  duracion_recorrido INTEGER NOT NULL, \
  fecha_origen_recorrido TIMESTAMP NOT NULL, \
  id_estacion_origen INTEGER NOT NULL, \
  fecha_destino_recorrido TIMESTAMP NOT NULL, \
  id_estacion_destino INTEGER, \
  id_usuario INTEGER NOT NULL, \
  modelo_bicicleta TEXT, \
  FOREIGN KEY (id_estacion_origen) REFERENCES estaciones (id_estacion), \
  FOREIGN KEY (id_estacion_destino) REFERENCES estaciones (id_estacion), \
  FOREIGN KEY (id_usuario) REFERENCES usuarios (id_usuario) \
);"

# Creo índices secundarios en id_estacion_origen e id_estacion_destino
#indice_id_estacion_origen_sql = "CREATE INDEX idx_id_estacion_origen ON recorridos (id_estacion_origen);"
#indice_id_destino_origen_sql = "CREATE INDEX idx_id_estacion_destino ON recorridos (id_estacion_destino);"

# Creo indice secundario por id_usuario
indice_id_usuario_sql = "CREATE INDEX idx_id_usuario ON recorridos (id_usuario);"

cursor = conn.cursor()
cursor.execute(create_recorridos_sql)
cursor.execute(indice_id_usuario_sql)

# %%
cursor.executemany("INSERT INTO recorridos VALUES(?, ?, ?, ?, ?, ?, ?, ?)", df_tours_tomados.values)
conn.commit()

# %% [markdown]
# # Consultas SQL

# %%
# Relación entre la duración de los viajes y el modelo de bicicleta.
# [(1405.72, 'FIT'), (1337.66, 'ICONIC')]

# En esta consulta, no afecta los missing values de id estacion destino
res = cursor.execute(
    "SELECT ROUND(AVG(duracion_recorrido), 2) as tiempo_promedio_de_viaje, modelo_bicicleta \
    FROM recorridos \
    GROUP BY modelo_bicicleta;")

res.fetchall()
# Out:
# [(1405.72, 'FIT'), (1337.66, 'ICONIC')]

# %%
# Relación entre la edad de los usuarios y la cantidad de viajes que realizaron.
# [(10, 14), (38, 15), (108, 16), (297, 17) ...

res = cursor.execute(
    "SELECT COUNT(re.duracion_recorrido) as cantidad_de_viajes, us.edad \
    FROM recorridos as re, usuarios as us \
    WHERE re.id_usuario = us.id_usuario AND \
    re.id_estacion_origen != re.id_estacion_destino \
    GROUP BY us.edad \
    ORDER BY us.edad \
    LIMIT 10;")

res.fetchall()
# Out:
# [(10, 14),
#  (38, 15),
#  (108, 16),
#  (297, 17),
#  (16527, 18),
#  (34035, 19),
#  (32992, 20),
#  (30791, 21),
#  (28273, 22),
#  (25479, 23)]

# %%
# Relación entre la cantidad de viajes realizados y la fecha de alta de los usuarios.

res = cursor.execute(
    "SELECT COUNT(re.duracion_recorrido) as cantidad_de_viajes, strftime('%m', us.fecha_alta) as mes \
    FROM recorridos as re, usuarios as us \
    WHERE re.id_usuario = us.id_usuario \
    GROUP BY mes \
    ORDER BY mes;")

res.fetchall()
# Out:
# [(87407, '01'),
#  (65649, '02'),
#  (67062, '03'),
#  (55304, '04'),
#  (51592, '05'),
#  (44727, '06'),
#  (51052, '07'),
#  (45229, '08'),
#  (49909, '09'),
#  (53125, '10'),
#  (41567, '11'),
#  (23740, '12')]

# %%
# Comunas que más viajes reciben

res = cursor.execute(
    "SELECT est.comuna, COUNT(re.id_estacion_destino) as llegadas_a_comuna \
    FROM recorridos as re, estaciones as est \
    WHERE re.id_estacion_destino = est.id_estacion \
    GROUP BY est.comuna \
    ORDER BY llegadas_a_comuna DESC;")

res.fetchall()
# Out:
# [(1, 601097),
#  (14, 447395),
#  (13, 230560),
#  (2, 229393),
#  (3, 179214),
#  (5, 167641),
#  (15, 165388),
#  (6, 134064),
#  (4, 114899),
#  (12, 112725),
#  (7, 80038),
#  (11, 75790),
#  (10, 57314),
#  (9, 15626),
#  (8, 6569)]

# %%
# Comunas de las que más viajes parten

res = cursor.execute(
    "SELECT est.comuna, COUNT(re.id_estacion_origen) as partidas_de_comuna \
    FROM recorridos as re, estaciones as est \
    WHERE re.id_estacion_origen = est.id_estacion AND re.id_estacion_destino IS NOT NULL \
    GROUP BY est.comuna \
    ORDER BY partidas_de_comuna DESC;")

res.fetchall()
# Out:
# [(1, 617093),
#  (14, 442541),
#  (2, 233055),
#  (13, 227887),
#  (3, 186222),
#  (5, 169558),
#  (15, 167268),
#  (6, 133962),
#  (12, 110481),
#  (4, 103261),
#  (7, 77939),
#  (11, 73831),
#  (10, 55218),
#  (9, 13983),
#  (8, 5561)]

# %%
# Usuarios más activos durante 2023.

# NOTA: En esta query se podria aclarar que sean datos de 2023, extrayendo el anio de las fechas de origen y destino
# y pidiendo que sean del anio 2023. Pero como todo el dataset son datos de 2023, no hace falta.
# Salvo que se agreguen datos de otros anios.

res = cursor.execute(
    "SELECT id_usuario, COUNT(id_usuario) as cantidad_de_viajes \
    FROM recorridos \
    GROUP BY id_usuario \
    ORDER BY cantidad_de_viajes DESC \
    LIMIT 10;")

res.fetchall()
# Out:
# [(668737, 1122),
#  (89898, 924),
#  (362760, 900),
#  (373935, 877),
#  (28486, 803),
#  (13242, 782),
#  (730924, 776),
#  (3828, 718),
#  (12434, 718),
#  (926125, 713)]
